# %%
import pickle
import os

# %%
os.chdir('../models/ISIBrnoAIMT')

# %%
with open('PROGRESS_0.pickle', 'rb') as file:
    data = pickle.load(file)

print(f"Train AUPRC: {data[0]['train_auprc']}")
print(f"Valid AUPRC: {data[0]['valid_auprc']}")
# Out:
# Train AUPRC: 0.11016407919998841
# Valid AUPRC: 0.1760391967005796

# %%
with open('PROGRESS_1.pickle', 'rb') as file:
    data = pickle.load(file)

print(f"Train AUPRC: {data[0]['train_auprc']}")
print(f"Valid AUPRC: {data[0]['valid_auprc']}")
# Out:
# Train AUPRC: 0.1456699873038519
# Valid AUPRC: 0.24778418843634614

# %%
with open('PROGRESS_2.pickle', 'rb') as file:
    data = pickle.load(file)

print(f"Train AUPRC: {data[0]['train_auprc']}")
print(f"Valid AUPRC: {data[0]['valid_auprc']}")
# Out:
# Train AUPRC: 0.1278064469615041
# Valid AUPRC: 0.2308324825394673

# %% [markdown]
# # Test

# %%
os.chdir('models/ISIBrnoAIMT')

# %%
from models.ISIBrnoAIMT.team_code import load_model
